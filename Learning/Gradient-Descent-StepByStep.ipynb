# %%
import numpy as np
from sklearn.datasets import make_regression

# %%
X,y = make_regression(n_samples=4, n_features=1, n_informative=1, n_targets=1, noise=80, random_state=13)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# 26.15963284313262

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X), color='red')

# %%
y_pred = ((reg.coef_ * X) + 0).reshape(4)

# %%
y_pred
# Out:
# array([-55.81626194,  35.3997844 ,  -3.48684452,  59.05807568])

# %%
plt.scatter(X,y)
plt.plot(X,y_pred)
plt.plot(X,reg.predict(X))

# %%
m = reg.coef_
b = 0

# %%
loss_slope = -2 * np.sum(y - m * X.ravel() - b)
loss_slope
# Out:
# -209.27706274506096

# %%
lr = 0.1
step_size = loss_slope * lr
step_size
# Out:
# -20.927706274506097

# %%
b = b - step_size
b
# Out:
# 20.927706274506097

# %%
y_pred1 = ((reg.coef_ * X) + b).reshape(4)
y_pred1
# Out:
# array([-34.88855566,  56.32749067,  17.44086175,  79.98578195])

# %%
plt.scatter(X,y)
plt.plot(X,y_pred1)
plt.plot(X,y_pred)
plt.plot(X,reg.predict(X))

# %%
loss_slope = -2 * np.sum(y - m * X.ravel() - b)
loss_slope
# Out:
# -41.855412549012215

# %%
lr = 0.1
step_size = loss_slope * lr
step_size
# Out:
# -4.185541254901222

# %%
b = b - step_size
b
# Out:
# 25.113247529407317

# %%
y_pred2 = ((reg.coef_ * X) + b).reshape(4)
y_pred2
# Out:
# array([-30.70301441,  60.51303193,  21.62640301,  84.1713232 ])

# %%
plt.scatter(X,y)
plt.plot(X,y_pred2)
plt.plot(X,y_pred1)
plt.plot(X,y_pred)
plt.plot(X,reg.predict(X))

# %%
loss_slope = -2 * np.sum(y - m * X.ravel() - b)
step_size = loss_slope * lr
b = b - step_size
y_pred3 = ((reg.coef_ * X) + b).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,y_pred3)
plt.plot(X,y_pred2)
plt.plot(X,y_pred1)
plt.plot(X,y_pred)
plt.plot(X,reg.predict(X))

# %%
b
# Out:
# 25.95035578038756

# %%
b = -100
m = 78.35
lr = 0.05

epochs = 10

for i in range(epochs):
    loss_slope = -2 * np.sum(y - m*X.ravel() - b)
    b = b - lr * loss_slope

    y_pred = (m * X + b)

    plt.plot(X,y_pred)

plt.scatter(X,y)
